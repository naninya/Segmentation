# %%
# Data Load:..

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("./drive/MyDrive/git_project/AnomalyDetectionApp/src")

# %%
data_dir = "../data/mvtec_original"

# %%
# Download Datasets

# %%
# https://www.mvtec.com/company/research/datasets/mvtec-ad/downloads
os.listdir(data_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c630bb146c88> in <cell line: 2>()
#       1 # https://www.mvtec.com/company/research/datasets/mvtec-ad/downloads
# ----> 2 os.listdir(data_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/mvtec_original'

# %%
os.makedirs("../data/mvtec_original", exist_ok=True)
# !tar -xf ../data/bottle.tar.xz -C ../data/mvtec_original
# !tar -xf ../data/grid.tar.xz -C ../data/mvtec_original
# !tar -xf ../data/zipper.tar.xz -C ../data/mvtec_original
# !tar -xf ../data/toothbrush.tar.xz -C ../data/mvtec_original
# !chmod 777 -R ../data
